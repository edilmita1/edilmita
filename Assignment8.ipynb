# %% [markdown]
# <a href="https://colab.research.google.com/github/edilmita/edilmita/blob/main/Assignment8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# In[1]:


# import the library
import pandas as pd


# In[2]:


# dataset source: https://www.kaggle.com/social-network-ads

# load the dataset
df = pd.read_csv('/content/Social_Network_Ads.csv')


# In[3]:


df.head() # display the dataset

#	User ID	Gender	Age	EstimatedSalary	Purchased
#0	15624510	Male	19	19000	0
#1	15810944	Male	35	20000	0
#2	15668575	Female	26	43000	0
#3	15603246	Female	27	57000	0
#4	15804002	Male	19	76000	0#


# In[4]:

df.isna().sum()  #



# In[5]:

df.dtypes

#User ID             int64
#Gender             object
#Age                 int64
#EstimatedSalary     int64
#Purchased           int64
#dtype: object


# In[6]:

df.corr() # used to find the pairwise correlation of all columns 
          # in the dataframe. Any na values are automatically excluded.
          # For any non-numeric data type columns in the dataframe 
          # it is ignored.Apr 22, 2020


#                 User ID	  Age	      EstimatedSalary	  Purchased
#User ID	        1.000000	-0.000721	    0.071097	    0.007120
#Age	            -0.000721	1.000000	    0.155238	    0.622454
#EstimatedSalary	0.071097	0.155238	    1.000000	    0.362083
#Purchased	      0.007120	0.622454	    0.362083	    1.000000

# In[7]:

x=sns.countplot(df['Purchased']) # Purchased Visual representation 


df['Purchased'].value_counts()

df.head()

from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Gender']=lb.fit_transform(df['Gender'])


df=df.drop(['User ID'],axis=1)

df.head()


# In[8]:

from sklearn.preprocessing import RobustScaler
rb=RobustScaler()
df['EstimatedSalary']=rb.fit_transform(df['EstimatedSalary'].values.reshape(-1,1))

df

from sklearn.preprocessing import StandardScaler
skc=StandardScaler()
df['Age']=skc.fit_transform(df['Age'].values.reshape(-1,1))

X=df.iloc[:,:-1].values

Y=df.iloc[:,-1].values


# In[9]:

from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.10, random_state=42)


from sklearn.svm import SVC
svc = SVC(kernel='poly')
svc.fit(X_train,y_train)
pred_svc =svc.predict(X_test)


from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, pred_svc))











from sklearn import naive_bayes
NB = naive_bayes.GaussianNB()
NB.fit(X_train,y_train)
pred_nb=NB.predict(X_test)
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, pred_nb))
Accuracy: 0.925
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, pred_nb)
array([[25,  2],
       [ 1, 12]])
from sklearn.metrics import classification_report,accuracy_score
print(classification_report(y_test,pred_nb))




# In[10]:


# fit the Logistic Regression model on Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 42)
classifier.fit(X_train, y_train)





# In[11]:


# Prediction on Test set
y_pred = classifier.predict(X_test)


# In[12]:


# Confusion Matrix
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
c_matrix = confusion_matrix(y_test, y_pred)


# In[10]:


c_matrix


# In[11]:


# classification report and result.
print(classification_report(y_test,y_pred))


# In[12]:


# accuracy of a model

print(round(accuracy_score(y_test,y_pred),2))


# - Hence, Accuracy of the model on test set is 85% and this model can be used to predict whether the customer will purchase a particular product or not.

# In[ ]:





















sklearn.preprocessing import StandardScaler
skc=StandardScaler()
df['Age']=skc.fit_transform(df['Age'].values.reshape(-1,1))

X=df.iloc[:,:-1].values

Y=df.iloc[:,-1].values
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.10, random_state=42)
from sklearn.svm import SVC
svc = SVC(kernel='poly')
svc.fit(X_train,y_train)
pred_svc =svc.predict(X_test)

from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, pred_svc))

# Accuracy: 0.9

from sklearn.metrics import classification_report,accuracy_score
print(classification_report(y_test,pred_svc))
# Out:
# Accuracy: 0.9
