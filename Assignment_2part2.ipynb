# %% [markdown]
# <a href="https://colab.research.google.com/github/edilmita/edilmita/blob/main/Assignment_2part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy.ma.core import 
from pandas.core.frame import DataFrame
import numpy as np # linear algebra
import pandas as pd # data processing, 

from google.colab import files
uploaded = files.upload()     #load the dataset
 
providedNutrition_dataset = pd.read_csv('nutrition_subset.csv')

#load the dataset provided
Nutrition_dataset = pd.read_csv('nutrition_subset.csv')

# Nutrition dataset info to find columns and count of the data 
Nutrition_dataset.info()

#Creating a contingency table without saving the output
pd.crosstab(Nutrition_dataset["saturated_fat"],Nutrition_dataset["cholesterol"])

#shows us the variable values of the first record in the bank_dataset
Nutrition_dataset.loc[0]

Nutrition_dataset.sort_values(by='saturated_fat', ascending=False, ignore_index=True, inplace=True)
Nutrition_dataset.head(5)



##                Part b

#Process in Excel
#Create a new variable in the dataframe called "saturated_fat_per_gram" 
#by dividing the amount of saturated fat by the weight in grams.
#Sort the entire dataframe based on the variable "saturated_fat_per_gram" 
#Process in Python
#and provide a list of the five food items with the highest content of saturated fat per gram.

from pandas.core.frame import DataFrame
import numpy as np # linear algebra
import pandas as pd # data processing, 

from google.colab import files
uploaded = files.upload()     #load the dataset
 
providedNutrition_dataset = pd.read_csv('nutrition_subset.csv')

#load the dataset provided
Nutrition_dataset = pd.read_csv('nutrition_subset.csv')

#Before I make a division i want to make sure is not a 0 value in the divisor.
Nutrition_dataset.sort_values(by='weight_in_grams', ascending=True, ignore_index=True, inplace=True)
Nutrition_dataset.head(5)
# the lowes umber Is:

0	PARSLEY; FREEZE-DRIED 1 TBSP	0.4	0.0	0
1	OREGANO 1 TSP	1.5	0.0	0
2	CURRY POWDER 1 TSP	2.0	0.0	0
3	IMITATION CREAMERS; POWDERED 1 TSP	2.0	0.7	0
4	CELERY SEED 1 TSP	2.0	0.0	0

print(Nutrition_dataset)

#I add the new column in excel and import  

from pandas.core.frame import DataFrame
import numpy as np # linear algebra
import pandas as pd # data processing, 

from google.colab import files
uploaded = files.upload()     #load the dataset
 
providedNutrition_dataset = pd.read_csv('Nutrition_new_column.csv')

#load the dataset provided
Nutrition_dataset = pd.read_csv('Nutrition_new_column.csv')

print(Nutrition_dataset)

Nutrition_dataset.sort_values(by='saturated_in_grams', ascending=False, ignore_index=True, inplace=True)
Nutrition_dataset.head(5)

##                   part c

#Process in Excel
#Create a new variable in the dataframe called "cholesterol_gram" 
#by dividing the amount of cholesterol by the weight in grams.
#Sort the entire dataframe based on the variable "cholesterol_gram" 
#Process in Python
#and provide a list of the five food items with the highest content of cholesterol per gram.

from pandas.core.frame import DataFrame
import numpy as np # linear algebra
import pandas as pd # data processing, 

from google.colab import files
uploaded = files.upload()     #load the dataset
 

#load the dataset provided
providedNutrition_dataset = pd.read_csv('nutrition_new_column.csv')

# Nutrition dataset info to find columns and count of the data 
Nutrition_dataset.info()

#print the data
print(Nutrition_dataset)

#sort the data by the cholesterol by weight in grams to show the first 5.
Nutrition_dataset.sort_values(by='cholesterol_grams', ascending=False, ignore_index=True, inplace=True)
Nutrition_dataset.head(5)

##       d

#Process in Excel
#Create a new variable in the dataframe called "standardized_saturated_fat_per_gram" 
# standardized_saturated_fat_per_gram = (saturated_fat_per_gram -saturated_fat_per_gram * mean()) / (saturated_fat_per_gram * std())
# Used Excel to find the outliers. 
#Sort the entire dataframe based on the variable "standardized_saturated_fat_per_gram" 
#Process in Python
#and provide a list of the Outliers food items with the highest #Create a new variable in the dataframe called "standardized_saturated_fat_per_gram" 

from pandas.core.frame import DataFrame
import numpy as np # linear algebra
import pandas as pd # data processing, 

from google.colab import files
uploaded = files.upload()     #load the dataset
 

#load the dataset provided
Nutrition_dataset = pd.read_csv('nutrition_Outliner_last.csv')

# Nutrition dataset info to find columns and count of the data 
Nutrition_dataset.info()

#print the data
print(Nutrition_dataset)

#Standardize the column "saturated_fat_per_gram"
#Provide a list of food items that are outliers at the higher end of the scale
#Number of food items that are outliers at the lower end of the scale


Nutrition_dataset.sort_values(by='standardized_saturated_fat_per_gram', ascending=False, ignore_index=True, inplace=True)

if ('standardized_saturated_fat_per_gram' < -0.05053):
    print ("food item", "standardized_saturated_fat_per_gram")


if ('standardized_saturated_fat_per_gram' > 0657923):
    print ("food item", "standardized_saturated_fat_per_gram")    

    #int("Number of outliers at the lower end of the scale is",df[df["standardized_saturated_fat_per_gram"] < -3].shape[0])
#print("Food items at are outliers at the higher end of the scale are")
#df[df["standardized_saturated_fat_per_gram"] > 3][["food item","standardized_saturated_fat_per_gram"]]

##                  e

#Standardize the column "cholesterol_per_gram"
#Provide a list of food items that are outliers at the higher end of the scale

#Process in Excel
#Create a new variable in the dataframe called "standardized_cholesterol_per_gram" 
# standardized_cholesterol_per_gram = (standardized_cholesterol_per_gram - standardized_cholesterol_per_gram * mean()) / (standardized_cholesterol_per_gram * std())
# Used Excel to find the outliers. 
#Sort the entire dataframe based on the variable "standardized_cholesterol_per_gram" 
#Process in Python
#and provide a list of the Outliers food items with the highest #Create a new variable in the dataframe called "standardized_saturated_fat_per_gram" 

from pandas.core.frame import DataFrame
import numpy as np # linear algebra
import pandas as pd # data processing, 

from google.colab import files
uploaded = files.upload()     #load the dataset
 

#load the dataset provided
Nutrition_dataset = pd.read_csv('nutrition_Outliner_last.csv')

# Nutrition dataset info to find columns and count of the data 
Nutrition_dataset.info()

#print the data
print(Nutrition_dataset)

#Standardize the column "saturated_fat_per_gram"
#Provide a list of food items that are outliers at the higher end of the scale
#Number of food items that are outliers at the lower end of the scale


Nutrition_dataset.sort_values(by='standardized_saturated_fat_per_gram', ascending=False, ignore_index=True, inplace=True)

if ('standardized_cholesterol_per_gram' < -0.05053):
    print ("food item", "standardized_saturated_fat_per_gram")


if ('standardized_cholesterol_per_gram' > 0657923):
    print ("food item", "standardized_saturated_fat_per_gram")    

#print("Food items at are outliers at the higher end of the scale are")
# Out:
#      <input type="file" id="files-a78853c2-7c5d-4867-8c6c-3180b7f18f3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a78853c2-7c5d-4867-8c6c-3180b7f18f3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nutrition_Outliner_last.csv to nutrition_Outliner_last.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   food item                            85 non-null     object
#  1   weight_in_grams                      85 non-null     float64
#  2   saturated_fat                        85 non-null     float64
# ...
